# %% [markdown]
# ### Multi-Agent Customer Support System with Agent-to-Agent Coordination
#
# This notebook demonstrates:
# - Multi-agent orchestration with LangGraph
# - Dynamic MCP tool discovery via HTTP
# - Agent-to-Agent (A2A) coordination
# - Conversation memory
# - Customer data and support tickets
#
# **Architecture:** Agents call MCP Server directly via HTTP REST API (no client layer needed)

# %%
# Imports
import os
import sys
from dotenv import load_dotenv

# Load environment
load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

if api_key:
    print(f"✅ OpenAI API Key loaded successfully")
else:
    print("❌ OpenAI API Key not found!")
    sys.exit(1)
# Out:
# ✅ OpenAI API Key loaded successfully

# %% [markdown]
# ### MCP Server: HTTP-based Tool Discovery
#
# **Note:** Make sure MCP server is running:
# ```bash
# python customer_mcp/server/mcp_server.py
# ```
#
# Agents call the MCP server directly via HTTP REST API.

# %%
import requests

# MCP Server URL
MCP_SERVER_URL = "http://localhost:8001"

# List all tools from MCP server
print("\n Fetching tools from MCP Server...")
response = requests.get(f"{MCP_SERVER_URL}/tools")
tools_data = response.json()

all_tools = tools_data.get("tools", [])
print(f"\nTotal tools available: {len(all_tools)}")
for tool in all_tools:
    print(f"   • {tool['name']}")

# Filter customer data tools
customer_tools = [t for t in all_tools if t['name'] in ['get_customer', 'list_customers', 'add_customer', 'update_customer']]
print(f"\nCustomer Data Agent tools: {len(customer_tools)}")
for tool in customer_tools:
    print(f"   • {tool['name']}")

# Test a tool call via HTTP
print("\nTesting tool call via HTTP...")
result = requests.post(
    f"{MCP_SERVER_URL}/tools/list_customers",
    json={"arguments": {"limit": 3}}
)
tool_result = result.json()
print(f"Tool call successful! Result: {tool_result}")
# Out:
#  Fetching tools from MCP Server...
#
# Total tools available: 7
#    • get_customer
#    • get_customer_history
#    • list_customers
#    • add_customer
#    • update_customer
#    • create_ticket
#    • fallback_sql
#
# Customer Data Agent tools: 4
#    • get_customer
#    • list_customers
#    • add_customer
#    • update_customer
#
# Testing tool call via HTTP...
# Tool call successful! Result: {'success': True, 'customers': [{'name': '', 'email': None, 'phone': None}, {'name': '', 'email': None, 'phone': None}, {'name': '', 'email': None, 'phone': None}], 'count': 3}

# %% [markdown]
# ### LANGGRAPH ORCHESTRATOR

# %%
from a2a.langgraph_orchestrator import LangGraphOrchestrator

#initialize the orchestrator
orchestrator = LangGraphOrchestrator()

# %% [markdown]
# ### Test Queries

# %%
print("\n<b>Simple Queries:</b>")

queries = [
    "Get me details about customer 4",
    "Show me all active customers",
]

for i, query in enumerate(queries, 1):
    print(f"\nQuery {i}: {query}")
    result = orchestrator.process(query, thread_id=f"simple_{i}")
    print(f"   -> Route: {result['route']}")
    print(f"   -> Response: {result['response'][:300]}...")
# Out:
# <b>Simple Queries:</b>
#
# Query 1: Get me details about customer 4
#  Routing to: customer_data (agent will coordinate with others if needed)
#    -> Route: customer_data
#    -> Response: Here are the details for customer 4:
#
# - **Name:** Alice Williams
# - **Email:** alice.w@techcorp.com
# - **Phone:** +1-555-0104
# - **Status:** Active
# - **Created At:** December 3, 2025, 07:15:04
# - **Updated At:** December 3, 2025, 07:15:04...
#
# Query 2: Show me all active customers
#  Routing to: customer_data (agent will coordinate with others if needed)
#    -> Route: customer_data
#    -> Response: Here are all the active customers:
#
# 1. **Alice Williams**
#    - Email: alice.w@techcorp.com
#    - Phone: +1-555-0104
#
# 2. **Charlie Brown**
#    - Email: newemail@example.com
#    - Phone: +1-555-0105
#
# 3. **Deepali Dagar**
#    - Email: deepali@uchi@edu
#    - Phone: N/A
#
# 4. **Diana Prince**
#    - Email: diana....

# %%
queries = [
    "I'am customer 5, having login issues",
]

for i, query in enumerate(queries, 1):
    print(f"\nQuery {i}: {query}")
    result = orchestrator.process(query, thread_id=f"simple_{i}")
    print(f"   -> Route: {result['route']}")
    print(f"   -> Response: {result['response'][:300]}...")
# Out:
# Query 1: I'am customer 5, having login issues
#  Routing to: support (agent will coordinate with others if needed)
#     📤 [support_agent] → [customer_data]: Get details for customer with ID 5.
#     📥 [customer_data] → [support_agent]: Completed request: Get details for customer with ID 5....
#    -> Route: support
#    -> Response: I have created a support ticket for you regarding the login issues. Here are the details:
#
# - **Ticket ID:** 63
# - **Issue:** Customer is experiencing login issues.
# - **Priority:** High
# - **Status:** Open
#
# Our support team will look into this issue as soon as possible. If you have any more questions o...

# %%
# complex queries
queries = [
    "Show cutsomer 5's details and their ticket history"
]

for i, query in enumerate(queries, 1):
    print(f"\nQuery {i}: {query}")
    result = orchestrator.process(query, thread_id=f"simple_{i}")
    print(f"   -> Route: {result['route']}")
    print(f"   -> Response: {result['response'][:300]}...")
# Out:
# Query 1: Show cutsomer 5's details and their ticket history
#  Routing to: customer_data (agent will coordinate with others if needed)
#     📤 [customer_data_agent] → [support]: Get ticket history for customer 5
#     📥 [support] → [customer_data_agent]: Completed request: Get ticket history for customer 5...
#    -> Route: customer_data
#    -> Response: ### Customer 5 Details:
# - **Name:** Charlie Brown
# - **Email:** newemail@example.com
# - **Phone:** +1-555-0105
# - **Status:** Active
# - **Created At:** December 3, 2025, 07:15:04
# - **Updated At:** December 5, 2025, 00:54:09
#
# ### Ticket History:
# Here are the tickets associated with customer 5:
#
# 1. **Tick...

# %% [markdown]
# ### Agent-to-Agent Coordination

# %%
print("\nComplex query requiring BOTH customer data AND tickets:")
print("   Query: 'Get customer 5's data with complete ticket history'")
print("   Expected: customer_data agent asks support agent for help\n")

result = orchestrator.process(
    "Get customer 5's data with complete ticket history",
    thread_id="a2a_demo"
)

print(f"   -> Primary Agent: {result['route']}")
print(f"   -> A2A Coordination: Observed")
print(f"   -> Response: {result['response'][:500]}...")
# Out:
# Complex query requiring BOTH customer data AND tickets:
#    Query: 'Get customer 5's data with complete ticket history'
#    Expected: customer_data agent asks support agent for help
#  Routing to: customer_data (agent will coordinate with others if needed)
#     📤 [customer_data_agent] → [support]: Get ticket history for customer with ID 5
#     📥 [support] → [customer_data_agent]: Completed request: Get ticket history for customer with ID 5...
#    -> Primary Agent: customer_data
#    -> A2A Coordination: Observed
#    -> Response: Here are the details for customer ID 5:
#
# ### Customer Information:
# - **Name:** Charlie Brown
# - **Email:** newemail@example.com
# - **Phone:** +1-555-0105
# - **Status:** Active
# - **Created At:** 2025-12-03 07:15:04
# - **Updated At:** 2025-12-05 00:54:09
#
# ### Ticket History:
# 1. **Ticket ID:** 8
#    - **Issue:** Email notifications not being received
#    - **Status:** Open
#    - **Priority:** Medium
# ...

# %% [markdown]
# ## Priority Assignment
#
# The system now automatically determines ticket priority based on issue severity. The LLM analyzes the scenario and assigns:
#
# - **HIGH**: Login issues, account locked, payment failures, data loss
# - **MEDIUM**: Bugs, performance issues, billing questions
# - **LOW**: Feature requests, general questions, minor issues

# %%
# Test intelligent priority assignment across different scenarios
test_scenarios = [
    ("I'm customer 5, having login issues - can't access my account", "HIGH"),
    ("I'm customer 5, dashboard is loading slowly", "MEDIUM"),
]

print("Testing  Priority Assignment\n \n")

for query, expected in test_scenarios:
    print(f"\n Query: {query}")
    print(f"   Expected Priority: {expected}")
    
    result = orchestrator.process(query, thread_id=f"priority_test")
    print(f"   -> Route: {result['route']}")
    print(f"   -> Response: {result['response'][:250]}...")
    print("-" * 70)
# Out:
# Testing  Priority Assignment
#
#
#
#  Query: I'm customer 5, having login issues - can't access my account
#    Expected Priority: HIGH
#  Routing to: support (agent will coordinate with others if needed)
#     📤 [support_agent] → [customer_data]: Customer 5 is experiencing ongoing login issues. Please check the account status and any locked state.
#     📤 [customer_data_agent] → [support]: Customer 5 (Charlie Brown) is experiencing login issues. Please check if this account is locked or if there are any other issues affecting the login.
#     📥 [customer_data] → [support_agent]: Completed request: Customer 5 is experiencing ongoing login issues. P...
#    -> Route: support
#    -> Response: I've created a support ticket for your login issue, with the ID **64**.
#
# Your account (under the name Charlie Brown) is active and not locked. Here are some suggestions to try resolving the login issue:
# - Attempt to reset your password.
# - Check if t...
# ...

# %% [markdown]
# ### Conversation memory

# %%
thread = "memory_demo"

print("\n Turn 1: Get customer info")
result1 = orchestrator.process(
    "Get me information about customer 3",
    thread_id=thread
)
print(f"  -> Response: {result1['response'][:100]}...")

print("\n Turn 2: Create ticket (uses context!)")
result2 = orchestrator.process(
    "Create a high priority ticket for them about password reset",
    thread_id=thread
)
print(f"  ->   Response: {result2['response'][:100]}...")
print("  -> Agent understood 'them' = customer 3!")

print("\n Turn 3: Follow up (still has context!)")
result3 = orchestrator.process(
    "What's their email address?",
    thread_id=thread
)
print(f"  -> Response: {result3['response']}")
print("  -> Agent still remembers customer 3!")
# Out:
#  Turn 1: Get customer info
#  Routing to: customer_data (agent will coordinate with others if needed)
#   -> Response: Here is the information about customer 3:
#
# - **Name:** Bob Johnson
# - **Email:** bob.johnson@example....
#
#  Turn 2: Create ticket (uses context!)
#  Routing to: support (agent will coordinate with others if needed)
#   ->   Response: I have created a high priority ticket for Bob Johnson regarding the password reset request due to th...
#   -> Agent understood 'them' = customer 3!
#
#  Turn 3: Follow up (still has context!)
#  Routing to: customer_data (agent will coordinate with others if needed)
#   -> Response: The email address for Bob Johnson is bob.johnson@example.com.
#   -> Agent still remembers customer 3!

# %% [markdown]
# ### Complex SQL Queries
# Created fallback sql query generating which allows more analytical questions (doesnt allow deletion or truncating queries -> returns them as dangerous)

# %%
sql_queries = [
    "Find customers whose name starts with 'A'",
    "Show me customer with more than 10 tickets"
]

for query in sql_queries:
    print(f"\n Query: {query}")
    result = orchestrator.process(query, thread_id="sql_demo")
    print(f"  -> Route: {result['route']}")
    print(f"  -> Response: {result['response'][:150]}...")
# Out:
#  Query: Find customers whose name starts with 'A'
#  Routing to: sql (agent will coordinate with others if needed)
#   -> Route: sql
#   -> Response: SQL Query Executed:
# ```sql
# SELECT * FROM customers WHERE name LIKE 'A%'
# ```
#
# Found 1 result(s):
#
# 1. id: 4, name: Alice Williams, email: alice.w@techco...
#
#  Query: Show me customer with more than 10 tickets
#  Routing to: sql (agent will coordinate with others if needed)
#   -> Route: sql
#   -> Response: SQL Query Executed:
# ```sql
# SELECT c.*
# FROM customers c
# WHERE (SELECT COUNT(*) FROM tickets WHERE customer_id = c.id) > 10
# ```
#
# Found 1 result(s):
#
# 1...

# %% [markdown]
# ### A2A COMMUNICATION LOG

# %%
from a2a.a2a_logger import get_a2a_logger

# Run complex query
result = orchestrator.process(
    "Tell me about customer 2 and their open tickets",
    thread_id="a2a_log"
)

# Show A2A summary
logger = get_a2a_logger()
logger.print_summary()
# Out:
#  Routing to: customer_data (agent will coordinate with others if needed)
#     📤 [customer_data_agent] → [support]: Get open tickets for customer with ID 2.
#     📥 [support] → [customer_data_agent]: Completed request: Get open tickets for customer with ID 2....
#
# ...
#   📊 A2A COMMUNICATION SUMMARY
# ...
#
# Session Start: 2025-12-04T18:51:21.400878
# Total Events: 78
#
# Event Breakdown:
#   • request: 52
#   • response: 26
#
# Agents Involved:
#   • support
#   • customer_data_agent
#   • support_agent
#   • customer_data
# ...

# %% [markdown]
# ## Test scenerios provided
# - Simple Query: "Get customer information for ID 5"
# Single agent, straightforward MCP call
# - Coordinated Query: "I'm customer 12345 and need help upgrading my account"
# Multiple agents coordinate: data fetch + support response
# - Complex Query: "Show me all active customers who have open tickets"
# Requires negotiation between data and support agents
# - Escalation: "I've been charged twice, please refund immediately!"
# Router must identify urgency and route appropriately
# - Multi-Intent: "Update my email to new@email.com and show my ticket history"
# Parallel task execution and coordination

# %%
import time
# Test Scenario 1: Simple Query
print("\n" + "=" * 80)
print("TEST 1: Simple Query - Single Agent")
print("=" * 80)
query1 = "Get customer information for ID 5"
print(f"Query: {query1}\n")

start = time.time()
result1 = orchestrator.process(query1, thread_id="test_simple")
elapsed = time.time() - start

print(f" Route: {result1['route']}")
print(f" Time: {elapsed:.2f}s")
print(f" Response:\n{result1['response']}\n")

# Test Scenario 2: Coordinated Query
print("=" * 80)
print("TEST 2: Coordinated Query - Multiple Agent Coordination")
print("=" * 80)
query2 = "I'm customer 5 and need help upgrading my account"
print(f"Query: {query2}\n")

start = time.time()
result2 = orchestrator.process(query2, thread_id="test_coordinated")
elapsed = time.time() - start

print(f" Route: {result2['route']}")
print(f" Time: {elapsed:.2f}s")
print(f" Response:\n{result2['response']}\n")
# Out:
# ...
# TEST 1: Simple Query - Single Agent
# ...
# Query: Get customer information for ID 5
#
#  Routing to: customer_data (agent will coordinate with others if needed)
#  Route: customer_data
#  Time: 5.78s
#  Response:
# Here is the customer information for ID 5:
#
# - **Name:** Charlie Brown
# - **Email:** newemail@example.com
# - **Phone:** +1-555-0105
# - **Status:** Active
# - **Created At:** December 3, 2025, 07:15:04
# - **Updated At:** December 5, 2025, 00:54:09
#
# ...
# TEST 2: Coordinated Query - Multiple Agent Coordination
# ...
# Query: I'm customer 5 and need help upgrading my account
#
#  Routing to: customer_data (agent will coordinate with others if needed)
#     📤 [customer_data_agent] → [support]: Customer 5, Charlie Brown, has requested help upgrading their account.
#     📤 [support_agent] → [customer_data]: Please provide the details for customer 5, Charlie Brown, including their current account type and upgrade options.
# ...

# %%
# Test Scenario 3: Complex Query: Negotiation
print("=" * 80)
print("TEST 3: Complex Query - Requires SQL Agent or Multi-Agent Negotiation")
print("=" * 80)
query3 = "Show me all active customers who have open tickets"
print(f"Query: {query3}\n")

start = time.time()
result3 = orchestrator.process(query3, thread_id="test_complex")
elapsed = time.time() - start

print(f" Route: {result3['route']}")
print(f" Time: {elapsed:.2f}s")
print(f" Response:\n{result3['response'][:500]}...\n")
# Out:
# ...
# TEST 3: Complex Query - Requires SQL Agent or Multi-Agent Negotiation
# ...
# Query: Show me all active customers who have open tickets
#
#  Routing to: customer_data (agent will coordinate with others if needed)
#     📤 [customer_data_agent] → [support]: Get open ticket history for the following customers: Alice Williams (alice.w@techcorp.com), Charlie Brown (newemail@example.com), Deepali Dagar (deepali@uchi@edu), Diana Prince (diana.prince@company.org), Edward Norton (e.norton@business.net), George Miller (george.m@enterprise.com), Hannah Lee (hannah.lee@global.com), Isaac Newton (isaac.n@science.edu), John Doe (john.doe@example.com), Julia Roberts (julia.r@movies.com), Laura Martinez (laura.m@solutions.com), Michael Scott (michael.scott@paper.com), Shinchan (deepali@gmail.com).
#     📤 [support_agent] → [customer_data]: Get customer ID for Alice Williams (alice.w@techcorp.com).
#     📤 [support_agent] → [customer_data]: Get customer ID for Charlie Brown (newemail@example.com).
# ...

# %%
# Test Scenario 4: Escalation: Urgent Priority
print("=" * 80)
print("TEST 4: Escalation - High Priority Detection")
print("=" * 80)
query4 = "I've been charged twice, please refund immediately!"
print(f"Query: {query4}\n")

start = time.time()
result4 = orchestrator.process(query4, thread_id="test_escalation")
elapsed = time.time() - start

print(f" Route: {result4['route']}")
print(f" Time: {elapsed:.2f}s")
print(f" Response:\n{result4['response']}\n")
print(" Priority should be: HIGH (payment failure)")
# Out:
# ...
# TEST 4: Escalation - High Priority Detection
# ...
# Query: I've been charged twice, please refund immediately!
#
#  Routing to: support (agent will coordinate with others if needed)
#  Route: support
#  Time: 3.30s
#  Response:
# I've created a support ticket regarding your issue of being charged twice, and it's assigned a medium priority. The ticket ID is **68**. Our team will look into your request for a refund as soon as possible.
#
#  Priority should be: HIGH (payment failure)

# %%
# Test Scenario 5: Multi-Intent: Parallel Execution
print("=" * 80)
print("TEST 5: Multi-Intent - Parallel Task Execution")
print("=" * 80)
query5 = "I'm customer 5, update my email to newemail@example.com and show my ticket history"
print(f"Query: {query5}\n")

start = time.time()
result5 = orchestrator.process(query5, thread_id="test_multi_intent")
elapsed = time.time() - start

print(f" Route: {result5['route']}")
print(f" Time: {elapsed:.2f}s")
print(f" Response:\n{result5['response']}\n")
print(" Should execute: UPDATE customer + GET ticket history")
# Out:
# ...
# TEST 5: Multi-Intent - Parallel Task Execution
# ...
# Query: I'm customer 5, update my email to newemail@example.com and show my ticket history
#
#  Routing to: customer_data (agent will coordinate with others if needed)
#     📤 [customer_data_agent] → [support]: Get ticket history for customer 5.
#     📥 [support] → [customer_data_agent]: Completed request: Get ticket history for customer 5....
#  Route: customer_data
#  Time: 73.88s
#  Response:
# Your email has been successfully updated to **newemail@example.com**.
#
# ### Ticket History for Customer 5:
# Here is your complete ticket history:
#
# 1. **Ticket ID**: 8
#    - **Issue**: Email notifications not being received
#    - **Status**: Open
#    - **Priority**: Medium
#    - **Created At**: 2025-12-03 07:15:04
#
# 2. **Ticket ID**: 17
#    - **Issue**: Typo in welcome email
#    - **Status**: Resolved
#    - **Priority**: Low
#    - **Created At**: 2025-12-03 07:15:04
#
# 3. **Ticket ID**: 26
#    - **Issue**: Connectivity
# ...

# %%
# Summary
print("\n" + "=" * 80)
print("  TEST SUMMARY")
print("=" * 80)
print(f" Test 1 (Simple):      {result1['route']} agent")
print(f" Test 2 (Coordinated): {result2['route']} agent")
print(f" Test 3 (Complex):     {result3['route']} agent")
print(f" Test 4 (Escalation):  {result4['route']} agent")
print(f"✓ Test 5 (Multi-Intent):{result5['route']} agent")
print("\n All test scenarios completed!")
# Out:
# ...
#   TEST SUMMARY
# ...
#  Test 1 (Simple):      customer_data agent
#  Test 2 (Coordinated): customer_data agent
#  Test 3 (Complex):     customer_data agent
#  Test 4 (Escalation):  support agent
# ✓ Test 5 (Multi-Intent):customer_data agent
#
#  All test scenarios completed!

# %% [markdown]
# ### SYSTEM ARCHITECTURE

# %%
from graphviz import Digraph
from IPython.display import display

dot = Digraph(comment='LangGraph Orchestrator Architecture')
dot.attr(rankdir='TB', fontsize='12')

# Main Orchestrator Box
dot.node('orch', 'LangGraph Orchestrator\n• Routes queries\n• Manages memory\n• Enables A2A', shape='box')

# Agents
dot.node('cust', 'Customer Data Agent', shape='box')
dot.node('supp', 'Support Agent', shape='box')
dot.node('sql', 'SQL Agent', shape='box')

# MCP Server (HTTP-based, no client layer)
dot.node('mcp_server', 'MCP Server (HTTP)\n• REST API\n• 7 Tools\n• Port 8001', shape='box', style='filled', fillcolor='lightblue')
dot.node('db', 'Database\n(SQLite)', shape='box')

# Edges - Agents call MCP Server directly via HTTP
dot.edge('orch', 'cust')
dot.edge('orch', 'supp')
dot.edge('orch', 'sql')

dot.edge('cust', 'mcp_server', label='HTTP')
dot.edge('supp', 'mcp_server', label='HTTP')
dot.edge('sql', 'mcp_server', label='HTTP')

dot.edge('mcp_server', 'db')

display(dot)
